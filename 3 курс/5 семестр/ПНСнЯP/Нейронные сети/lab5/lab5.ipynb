# %%
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils

# Устанавливаем seed для повторяемости результатов
numpy.random.seed(42)

# Загружаем данные
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Преобразование размерности изображений
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
# Нормализация данных
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Преобразуем метки в категории
Y_train = np_utils.to_categorical(y_train, 10)
Y_test = np_utils.to_categorical(y_test, 10)

# Создаем последовательную модель
model = Sequential()

# Добавляем уровни сети
model.add(Dense(1200, input_dim=784, activation="relu", kernel_initializer="normal"))
model.add(Dense(600,  activation="relu", kernel_initializer="normal"))
model.add(Dense(10, activation="softmax", kernel_initializer="normal"))

# Компилируем модель
model.compile(loss="categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])

print(model.summary())

# Обучаем сеть
model.fit(X_train, Y_train, batch_size=50, epochs=100, validation_split=0.2, verbose=2)

# Оцениваем качество обучения сети на тестовых данных
scores = model.evaluate(X_test, Y_test, verbose=0)
print("Точность работы на тестовых данных: %.2f%%" % (scores[1]*100))

# Генерируем описание модели в формате json
model_json = model.to_json()
# Записываем модель в файл
json_file = open("mnist_model.json", "w")
json_file.write(model_json)
json_file.close()

model.save_weights("mnist_model.h5")

print ("Сохранили Model")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 1200)              942000
# _________________________________________________________________
# dense_5 (Dense)              (None, 600)               720600
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                6010
# =================================================================
# Total params: 1,668,610
# Trainable params: 1,668,610
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 960/960 - 19s - loss: 0.6152 - accuracy: 0.8451 - val_loss: 0.3153 - val_accuracy: 0.9125
# Epoch 2/100
# 960/960 - 18s - loss: 0.2994 - accuracy: 0.9168 - val_loss: 0.2540 - val_accuracy: 0.9293
# Epoch 3/100
# 960/960 - 18s - loss: 0.2471 - accuracy: 0.9309 - val_loss: 0.2214 - val_accuracy: 0.9382
# Epoch 4/100
# 960/960 - 18s - loss: 0.2154 - accuracy: 0.9390 - val_loss: 0.1993 - val_accuracy: 0.9443
# Epoch 5/100
# 960/960 - 19s - loss: 0.1915 - accuracy: 0.9455 - val_loss: 0.1799 - val_accuracy: 0.9488
# Epoch 6/100
# 960/960 - 19s - loss: 0.1728 - accuracy: 0.9505 - val_loss: 0.1700 - val_accuracy: 0.9512
# Epoch 7/100
# 960/960 - 18s - loss: 0.1566 - accuracy: 0.9555 - val_loss: 0.1575 - val_accuracy: 0.9558
# Epoch 8/100
# 960/960 - 18s - loss: 0.1436 - accuracy: 0.9595 - val_loss: 0.1465 - val_accuracy: 0.9600
# Epoch 9/100
# 960/960 - 19s - loss: 0.1318 - accuracy: 0.9636 - val_loss: 0.1405 - val_accuracy: 0.9621
# Epoch 10/100
# 960/960 - 18s - loss: 0.1218 - accuracy: 0.9665 - val_loss: 0.1340 - val_accuracy: 0.9625
# Epoch 11/100
# 960/960 - 18s - loss: 0.1133 - accuracy: 0.9688 - val_loss: 0.1287 - val_accuracy: 0.9652
# Epoch 12/100
# 960/960 - 19s - loss: 0.1054 - accuracy: 0.9707 - val_loss: 0.1226 - val_accuracy: 0.9658
# Epoch 13/100
# 960/960 - 18s - loss: 0.0980 - accuracy: 0.9731 - val_loss: 0.1192 - val_accuracy: 0.9678
# Epoch 14/100
# 960/960 - 18s - loss: 0.0917 - accuracy: 0.9753 - val_loss: 0.1150 - val_accuracy: 0.9688
# Epoch 15/100
# 960/960 - 18s - loss: 0.0862 - accuracy: 0.9773 - val_loss: 0.1093 - val_accuracy: 0.9682
# Epoch 16/100
# 960/960 - 19s - loss: 0.0805 - accuracy: 0.9789 - val_loss: 0.1111 - val_accuracy: 0.9688
# Epoch 17/100
# 960/960 - 19s - loss: 0.0757 - accuracy: 0.9801 - val_loss: 0.1086 - val_accuracy: 0.9693
# Epoch 18/100
# 960/960 - 19s - loss: 0.0715 - accuracy: 0.9814 - val_loss: 0.1043 - val_accuracy: 0.9712
# Epoch 19/100
# 960/960 - 18s - loss: 0.0675 - accuracy: 0.9824 - val_loss: 0.1020 - val_accuracy: 0.9717
# Epoch 20/100
# 960/960 - 18s - loss: 0.0637 - accuracy: 0.9836 - val_loss: 0.1001 - val_accuracy: 0.9712
# Epoch 21/100
# 960/960 - 18s - loss: 0.0600 - accuracy: 0.9851 - val_loss: 0.0978 - val_accuracy: 0.9727
# Epoch 22/100
# 960/960 - 18s - loss: 0.0568 - accuracy: 0.9859 - val_loss: 0.0960 - val_accuracy: 0.9728
# Epoch 23/100
# 960/960 - 18s - loss: 0.0538 - accuracy: 0.9868 - val_loss: 0.0941 - val_accuracy: 0.9728
# Epoch 24/100
# 960/960 - 19s - loss: 0.0511 - accuracy: 0.9880 - val_loss: 0.0922 - val_accuracy: 0.9741
# Epoch 25/100
# 960/960 - 18s - loss: 0.0485 - accuracy: 0.9889 - val_loss: 0.0907 - val_accuracy: 0.9740
# Epoch 26/100
# 960/960 - 18s - loss: 0.0460 - accuracy: 0.9892 - val_loss: 0.0909 - val_accuracy: 0.9744
# Epoch 27/100
# 960/960 - 18s - loss: 0.0436 - accuracy: 0.9900 - val_loss: 0.0893 - val_accuracy: 0.9737
# Epoch 28/100
# 960/960 - 18s - loss: 0.0414 - accuracy: 0.9909 - val_loss: 0.0893 - val_accuracy: 0.9737
# Epoch 29/100
# 960/960 - 18s - loss: 0.0394 - accuracy: 0.9913 - val_loss: 0.0869 - val_accuracy: 0.9754
# Epoch 30/100
# 960/960 - 18s - loss: 0.0374 - accuracy: 0.9921 - val_loss: 0.0860 - val_accuracy: 0.9755
# Epoch 31/100
# 960/960 - 18s - loss: 0.0356 - accuracy: 0.9924 - val_loss: 0.0857 - val_accuracy: 0.9758
# Epoch 32/100
# 960/960 - 18s - loss: 0.0339 - accuracy: 0.9931 - val_loss: 0.0846 - val_accuracy: 0.9756
# Epoch 33/100
# 960/960 - 19s - loss: 0.0324 - accuracy: 0.9935 - val_loss: 0.0865 - val_accuracy: 0.9752
# Epoch 34/100
# 960/960 - 18s - loss: 0.0308 - accuracy: 0.9940 - val_loss: 0.0842 - val_accuracy: 0.9758
# Epoch 35/100
# 960/960 - 18s - loss: 0.0295 - accuracy: 0.9941 - val_loss: 0.0834 - val_accuracy: 0.9757
# Epoch 36/100
# 960/960 - 18s - loss: 0.0279 - accuracy: 0.9945 - val_loss: 0.0838 - val_accuracy: 0.9752
# Epoch 37/100
# 960/960 - 19s - loss: 0.0266 - accuracy: 0.9951 - val_loss: 0.0827 - val_accuracy: 0.9762
# Epoch 38/100
# 960/960 - 18s - loss: 0.0255 - accuracy: 0.9957 - val_loss: 0.0817 - val_accuracy: 0.9756
# Epoch 39/100
# 960/960 - 18s - loss: 0.0241 - accuracy: 0.9959 - val_loss: 0.0819 - val_accuracy: 0.9761
# Epoch 40/100
# 960/960 - 18s - loss: 0.0232 - accuracy: 0.9962 - val_loss: 0.0826 - val_accuracy: 0.9754
# Epoch 41/100
# 960/960 - 18s - loss: 0.0222 - accuracy: 0.9964 - val_loss: 0.0819 - val_accuracy: 0.9763
# Epoch 42/100
# 960/960 - 18s - loss: 0.0214 - accuracy: 0.9966 - val_loss: 0.0807 - val_accuracy: 0.9760
# Epoch 43/100
# 960/960 - 18s - loss: 0.0203 - accuracy: 0.9968 - val_loss: 0.0800 - val_accuracy: 0.9772
# Epoch 44/100
# 960/960 - 18s - loss: 0.0195 - accuracy: 0.9974 - val_loss: 0.0805 - val_accuracy: 0.9760
# Epoch 45/100
# 960/960 - 19s - loss: 0.0187 - accuracy: 0.9974 - val_loss: 0.0796 - val_accuracy: 0.9771
# Epoch 46/100
# 960/960 - 18s - loss: 0.0178 - accuracy: 0.9976 - val_loss: 0.0807 - val_accuracy: 0.9763
# Epoch 47/100
# 960/960 - 18s - loss: 0.0172 - accuracy: 0.9978 - val_loss: 0.0798 - val_accuracy: 0.9770
# Epoch 48/100
# 960/960 - 20s - loss: 0.0164 - accuracy: 0.9980 - val_loss: 0.0799 - val_accuracy: 0.9771
# Epoch 49/100
# 960/960 - 27s - loss: 0.0158 - accuracy: 0.9980 - val_loss: 0.0796 - val_accuracy: 0.9777
# Epoch 50/100
# 960/960 - 20s - loss: 0.0151 - accuracy: 0.9984 - val_loss: 0.0804 - val_accuracy: 0.9769
# Epoch 51/100
# 960/960 - 20s - loss: 0.0146 - accuracy: 0.9985 - val_loss: 0.0794 - val_accuracy: 0.9765
# Epoch 52/100
# 960/960 - 24s - loss: 0.0141 - accuracy: 0.9985 - val_loss: 0.0795 - val_accuracy: 0.9770
# Epoch 53/100
# 960/960 - 24s - loss: 0.0136 - accuracy: 0.9988 - val_loss: 0.0787 - val_accuracy: 0.9778
# Epoch 54/100
# 960/960 - 21s - loss: 0.0130 - accuracy: 0.9988 - val_loss: 0.0799 - val_accuracy: 0.9766
# Epoch 55/100
# 960/960 - 19s - loss: 0.0125 - accuracy: 0.9990 - val_loss: 0.0796 - val_accuracy: 0.9765
# Epoch 56/100
# 960/960 - 19s - loss: 0.0121 - accuracy: 0.9990 - val_loss: 0.0787 - val_accuracy: 0.9771
# Epoch 57/100
# 960/960 - 19s - loss: 0.0117 - accuracy: 0.9991 - val_loss: 0.0791 - val_accuracy: 0.9776
# Epoch 58/100
# 960/960 - 18s - loss: 0.0112 - accuracy: 0.9992 - val_loss: 0.0795 - val_accuracy: 0.9772
# Epoch 59/100
# 960/960 - 18s - loss: 0.0107 - accuracy: 0.9993 - val_loss: 0.0800 - val_accuracy: 0.9775
# Epoch 60/100
# 960/960 - 18s - loss: 0.0105 - accuracy: 0.9994 - val_loss: 0.0798 - val_accuracy: 0.9768
# Epoch 61/100
# 960/960 - 18s - loss: 0.0101 - accuracy: 0.9994 - val_loss: 0.0795 - val_accuracy: 0.9774
# Epoch 62/100
# 960/960 - 22s - loss: 0.0098 - accuracy: 0.9995 - val_loss: 0.0794 - val_accuracy: 0.9773
# Epoch 63/100
# 960/960 - 19s - loss: 0.0095 - accuracy: 0.9995 - val_loss: 0.0792 - val_accuracy: 0.9780
# Epoch 64/100
# 960/960 - 19s - loss: 0.0091 - accuracy: 0.9996 - val_loss: 0.0792 - val_accuracy: 0.9779
# Epoch 65/100
# 960/960 - 18s - loss: 0.0088 - accuracy: 0.9996 - val_loss: 0.0793 - val_accuracy: 0.9782
# Epoch 66/100
# 960/960 - 18s - loss: 0.0086 - accuracy: 0.9997 - val_loss: 0.0792 - val_accuracy: 0.9782
# Epoch 67/100
# 960/960 - 18s - loss: 0.0083 - accuracy: 0.9996 - val_loss: 0.0792 - val_accuracy: 0.9782
# Epoch 68/100
# 960/960 - 18s - loss: 0.0080 - accuracy: 0.9997 - val_loss: 0.0794 - val_accuracy: 0.9782
# Epoch 69/100
# 960/960 - 18s - loss: 0.0078 - accuracy: 0.9997 - val_loss: 0.0792 - val_accuracy: 0.9781
# Epoch 70/100
# 960/960 - 18s - loss: 0.0076 - accuracy: 0.9997 - val_loss: 0.0800 - val_accuracy: 0.9780
# Epoch 71/100
# 960/960 - 18s - loss: 0.0074 - accuracy: 0.9997 - val_loss: 0.0803 - val_accuracy: 0.9778
# Epoch 72/100
# 960/960 - 18s - loss: 0.0071 - accuracy: 0.9998 - val_loss: 0.0795 - val_accuracy: 0.9787
# Epoch 73/100
# 960/960 - 18s - loss: 0.0069 - accuracy: 0.9997 - val_loss: 0.0797 - val_accuracy: 0.9787
# Epoch 74/100
# 960/960 - 18s - loss: 0.0067 - accuracy: 0.9998 - val_loss: 0.0798 - val_accuracy: 0.9783
# Epoch 75/100
# 960/960 - 18s - loss: 0.0066 - accuracy: 0.9998 - val_loss: 0.0800 - val_accuracy: 0.9778
# Epoch 76/100
# 960/960 - 18s - loss: 0.0064 - accuracy: 0.9998 - val_loss: 0.0803 - val_accuracy: 0.9783
# Epoch 77/100
# 960/960 - 18s - loss: 0.0062 - accuracy: 0.9998 - val_loss: 0.0801 - val_accuracy: 0.9783
# Epoch 78/100
# 960/960 - 19s - loss: 0.0061 - accuracy: 0.9999 - val_loss: 0.0808 - val_accuracy: 0.9778
# Epoch 79/100
# 960/960 - 18s - loss: 0.0059 - accuracy: 0.9999 - val_loss: 0.0799 - val_accuracy: 0.9788
# Epoch 80/100
# 960/960 - 18s - loss: 0.0058 - accuracy: 0.9999 - val_loss: 0.0801 - val_accuracy: 0.9784
# Epoch 81/100
# 960/960 - 19s - loss: 0.0056 - accuracy: 0.9999 - val_loss: 0.0801 - val_accuracy: 0.9784
# Epoch 82/100
# 960/960 - 18s - loss: 0.0055 - accuracy: 0.9999 - val_loss: 0.0800 - val_accuracy: 0.9784
# Epoch 83/100
# 960/960 - 18s - loss: 0.0054 - accuracy: 0.9999 - val_loss: 0.0804 - val_accuracy: 0.9785
# Epoch 84/100
# 960/960 - 18s - loss: 0.0052 - accuracy: 0.9999 - val_loss: 0.0809 - val_accuracy: 0.9782
# Epoch 85/100
# 960/960 - 19s - loss: 0.0051 - accuracy: 0.9999 - val_loss: 0.0809 - val_accuracy: 0.9782
# Epoch 86/100
# 960/960 - 18s - loss: 0.0050 - accuracy: 0.9999 - val_loss: 0.0806 - val_accuracy: 0.9786
# Epoch 87/100
# 960/960 - 18s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0809 - val_accuracy: 0.9783
# Epoch 88/100
# 960/960 - 18s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0812 - val_accuracy: 0.9783
# Epoch 89/100
# 960/960 - 19s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0806 - val_accuracy: 0.9786
# Epoch 90/100
# 960/960 - 19s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0809 - val_accuracy: 0.9785
# Epoch 91/100
# 960/960 - 18s - loss: 0.0044 - accuracy: 0.9999 - val_loss: 0.0810 - val_accuracy: 0.9779
# Epoch 92/100
# 960/960 - 18s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0810 - val_accuracy: 0.9785
# Epoch 93/100
# 960/960 - 18s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0811 - val_accuracy: 0.9784
# Epoch 94/100
# 960/960 - 18s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0809 - val_accuracy: 0.9787
# Epoch 95/100
# 960/960 - 23s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0815 - val_accuracy: 0.9783
# Epoch 96/100
# 960/960 - 20s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0817 - val_accuracy: 0.9782
# Epoch 97/100
# 960/960 - 22s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0815 - val_accuracy: 0.9783
# Epoch 98/100
# 960/960 - 19s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0817 - val_accuracy: 0.9783
# Epoch 99/100
# 960/960 - 19s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0817 - val_accuracy: 0.9787
# Epoch 100/100
# 960/960 - 18s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0820 - val_accuracy: 0.9785
# Точность работы на тестовых данных: 98.05%
# Сохранили Model
